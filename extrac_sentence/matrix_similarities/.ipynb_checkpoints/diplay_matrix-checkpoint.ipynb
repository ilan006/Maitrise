# %%
from numpy import genfromtxt
import pandas as pd
import time
path_directory = '../../../Data_Maitrise/Matrix_similarite/'# path of files' directory
path_data = '../../../Data_Maitrise/data_perso/'
import os
import json

from IPython.display import display

with open(path_data + 'data_Q_and_answer.json', 'r') as input:
    d = json.load(input)
    input.close()

# %%
print(files)
# Out:
# ['df571094b7a58dae1900cd6a67.csv', 'df5726bf325951b619008f7cff.csv', 'df572fadcbb2c2fd1400568329.csv', 'df57294279af94a219006aa20a.csv', 'df56beb4343aeaaa14008c925c.csv', 'df572fe41e04bcaa1900d76e4b.csv', 'df5726ae32708984140094cdad.csv', 'df5727c94bff5b5019007d954e.csv', 'df5727d0f73acd2414000ded14.csv', 'df571c8539dd7acb1400e4c0e2.csv', 'df5726f4a0708984140094d6ed.csv', 'df5733638fd058e614000b59eb.csv', 'df57286fa83acd2414000df9e5.csv', 'df5733cff84776f419006612b4.csv', 'df571c7d55dd7acb1400e4c0c7.csv', 'df5727213c708984140094da37.csv', 'df5726b929f1498d1400e8e8ea.csv', 'df572a10cd6aef051400155226.csv', 'df5726a7ecf1498d1400e8e656.csv', 'df57264a8cdd62a815002e808e.csv', 'df56e759bb00c9c71400d77002.csv', 'df5727fc37ff5b5019007d9a18.csv', 'df5727c69d3acd2414000dec15.csv', 'df5729e02f1d0469140077963b.csv', 'df5730bf03069b5314008322eb.csv', 'df571cbe35dd7acb1400e4c13c.csv', 'df572f6a0ba23a5019007fc5ec.csv', 'df57265e97708984140094c3c5.csv', 'df56e11f05e3433e1400422c31.csv', 'df572687e1
# ...

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

def display_matrix_sim(question_id,data_Q_answer):
    print('réponse  ',data_Q_answer[question_id][1])
    file = path_directory + 'df' + question_id + '.csv'
    df = pd.read_csv(file, sep=',')
    display(df)

# %%
question_id = '571094b7a58dae1900cd6a67'
display_matrix_sim(question_id,d)
# Out:
# réponse   ['prohibited emigration']
#     Unnamed: 0       how       did       the  revocation  restrict  huguenot  \
# 0          the  0.338904  0.347367  1.000000    0.285867  0.242038  0.295575
# 1   revocation  0.235389  0.254844  0.285867    1.000000  0.294788  0.295303
# 2      forbade  0.225428  0.331968  0.352123    0.330352  0.343081  0.464135
# 3   protestant  0.150378  0.230917  0.267921    0.315342  0.256837  0.545166
# 4     services  0.184398  0.144726  0.238148    0.260691  0.264040  0.148378
# 5            ,  0.226594  0.301509  0.493308    0.301042  0.227873  0.247522
# 6     required  0.299990  0.309237  0.278482    0.341101  0.414428  0.186938
# 7    education  0.124450  0.197623  0.239829    0.488786  0.238030  0.204700
# 8           of  0.248075  0.251390  0.733189    0.284407  0.226977  0.290612
# 9     children  0.166212  0.221139  0.156541    0.140128  0.142949  0.248660
# 10          as  0.337828  0.359647  0.483816    0.312444  0.251386  0.158220
# ...

# %%
question_id = '572fac17947a6a140053cb54'
display_matrix_sim(question_id,d)
# Out:
# réponse   ['Following a referendum in 1997', '1998']
#      Unnamed: 0      when       was       the   current  parliament        of  \
# 0     following  0.326350  0.164934  0.397794  0.245468    0.179371  0.357668
# 1             a  0.443974  0.450847  0.582920  0.198724    0.229512  0.505250
# 2    referendum  0.173553  0.241516  0.252065  0.227010    0.567384  0.218499
# 3            in  0.443133  0.455141  0.666239  0.195571    0.232315  0.569639
# 4          1997 -0.036533 -0.112452  0.017452  0.008452    0.044172 -0.003639
# 5             ,  0.366746  0.454561  0.493308  0.293414    0.254429  0.494608
# 6            in  0.443133  0.455141  0.666239  0.195571    0.232315  0.569639
# 7         which  0.572554  0.283096  0.652182  0.206676    0.202524  0.501163
# 8           the  0.509190  0.487115  1.000000  0.331441    0.265214  0.733189
# 9      scottish  0.120866  0.202298  0.217250  0.142959    0.341862  0.169846
# ...

# %%
question_id = '56f84760aef2371900625f84'
display_matrix_sim(question_id,d)
# Out:
# réponse   ['Zwickau prophets', 'Augustinian friars']
#        Unnamed: 0      what     group       was  responsible       for  \
# 0             the  0.427457  0.307955  0.487115     0.330510  0.473997
# 1         reforms  0.189932  0.116793  0.295846     0.195871  0.174086
# 2        provoked  0.218189  0.154107  0.267747     0.294208  0.242303
# 3    disturbances  0.283856  0.123087  0.183059     0.279151  0.176813
# 4               ,  0.308747  0.280983  0.454561     0.219228  0.446487
# 5       including  0.183288  0.292580  0.218847     0.252149  0.425071
# 6               a  0.332040  0.259476  0.450847     0.221193  0.440381
# 7          revolt  0.211335  0.130615  0.251983     0.075910  0.073233
# 8              by  0.245548  0.291573  0.475236     0.322678  0.324870
# 9             the  0.427457  0.307955  0.487115     0.330510  0.473997
# 10    augustinian  0.200992  0.180299  0.300529     0.132316  0.089166
# ...

# %%
question_id = '56e1066be3433e1400422ae7'
display_matrix_sim(question_id,d)
# Out:
# réponse   ['superintendent of New York City schools']
#         Unnamed: 0      what       was   maxwell        's       job         ?
# 0              the  0.427457  0.487115  0.176845 -0.015404  0.242427  0.220681
# 1             plan  0.294795  0.240772  0.081648  0.014385  0.249773  0.196105
# 2              was  0.221110  1.000000  0.222551  0.008975  0.239617  0.184121
# 3                ,  0.308747  0.454561  0.286124 -0.001613  0.271907  0.310912
# 4               at  0.283861  0.367078  0.126986 -0.084812  0.249664  0.219786
# 5            least  0.333716  0.207913  0.124852  0.058874  0.156451  0.288669
# 6    provisionally  0.234965  0.379353  0.122855  0.034753  0.176967  0.124874
# 7         approved  0.237957  0.272988  0.108672 -0.004867  0.253363  0.259144
# 8               by  0.245548  0.475236  0.179961 -0.010884  0.179978  0.179666
# 9             then  0.407269  0.270446  0.191711  0.010922  0.292620  0.288460
# ...

# %%
question_id = '5727213c708984140094da35'
display_matrix_sim(question_id,d)
# Out:
# réponse   ['Percy Shelley']
#    Unnamed: 0     after       the  peterloo  massacre      what      poet  \
# 0   following  0.396232  0.397794  0.189412  0.114340  0.250642  0.054264
# 1         the  0.456505  1.000000  0.351287  0.238702  0.427457  0.146150
# 2    peterloo  0.266330  0.351287  1.000000  0.275513  0.223001  0.182056
# 3    massacre  0.245225  0.238702  0.275513  1.000000  0.166818  0.145653
# 4          of  0.386746  0.733189  0.314055  0.205269  0.332908  0.168633
# 5        1819 -0.241259 -0.165492 -0.102356 -0.098210  0.053451 -0.062207
# 6           ,  0.388606  0.493308  0.307413  0.225448  0.308747  0.278953
# 7        poet  0.155135  0.146150  0.182056  0.145653  0.107964  1.000000
# 8       percy  0.198199  0.244035  0.159505  0.133353  0.156283  0.145398
# 9     shelley  0.188562  0.197346  0.160318  0.181712  0.171312  0.348996
# 10      wrote  0.178532  0.242694  0.188190  0.197300  0.266499  0.408766
# ...

# %%
question_id = '57299021af94a219006aa50e'
display_matrix_sim(question_id,d)
# Out:
# réponse   ["Vinogradov's theorem", "Vinogradov's"]
#       Unnamed: 0     which   theorem    states      that       all     large  \
# 0         weaker  0.287466  0.180445  0.194822  0.315660  0.167521  0.206173
# 1     statements  0.337326  0.331951  0.262518  0.440738  0.320107  0.118763
# 2           than  0.397468  0.159257  0.240147  0.489128  0.301762  0.281313
# 3           this  0.671943  0.203321  0.268485  0.690945  0.474626  0.344082
# 4           have  0.496527  0.182499  0.201624  0.618262  0.555946  0.339642
# 5           been  0.369940  0.093754  0.206741  0.415200  0.383391  0.315223
# 6         proven  0.258255  0.441742  0.144431  0.416946  0.258181  0.182135
# 7              ,  0.365800  0.160035  0.331513  0.413754  0.425625  0.226389
# 8            for  0.440956  0.153082  0.249644  0.413764  0.411440  0.229671
# 9        example  0.459431  0.246226  0.208614  0.429898  0.340536  0.309343
# ...
