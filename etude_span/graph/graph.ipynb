# %%
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set(style="darkgrid")

# %%
# titanic = sns.load_dataset('titanic')
# titanic.head()

# Load data
# csvfile = pd.read_csv('../fastText/resultat_ngrams_general.csv')
# csvfile.head()

# sns.barplot(x='n', y='avec repli',  data=csvfile)
# # Set up a factorplot
# g = sns.factorplot(spamreader[0], spamreader[1], data=spamreader, kind="bar", palette="muted", legend=False)
                   
# # Show plot
# plt.show()

# %%
csvfile = pd.read_csv('../../extrac_sentence/data_perso/freq_position_train.csv')
csvfile.head()
g = sns.factorplot(x='position relative', y='comptage relatif',hue = "class",legend=False,  data=csvfile, palette='Set1', kind='bar', aspect = 2.2)
# g.set_ylabels(text="compte")
plt.title("position relative de la phrase à trouver dans le paragraphe (TRAIN)" , size = 18)
g.set_xlabels(text="Position relative (en phrase)")

# %%
csvfile = pd.read_csv('position_span_phrases_dev.csv')
csvfile.head()
g = sns.factorplot(x='position relative', y='comptage relatif',hue = "class",legend=False,  data=csvfile, palette='Set1', kind='bar', aspect = 2.2)
# g.set_ylabels(text="compte")
plt.title("position relative de la phrase à trouver dans le paragraphe (DEV)" , size = 18)
g.set_xlabels(text="Position relative (en phrase)")

# %%
csvfile = pd.read_csv('../fastText/resultat_ngrams_general.csv')
csvfile.head()
sns.set(font_scale=5)
g = sns.factorplot(x='n', y='value', hue = 'class',  data=csvfile, palette='tab20', kind='bar',size=25, aspect=1.5)
plt.title("performance des differents systems" , size = 40)
g.set_xticklabels(step=5)
