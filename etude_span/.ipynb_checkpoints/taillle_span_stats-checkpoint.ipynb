# %%
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set(style="darkgrid")

# %%
csvfile = pd.read_csv('taille_span_dev.csv')
csvfile.head()
sns.set(font_scale=1)
g = sns.factorplot(x='taille', y='compte relatif',  data=csvfile, palette='plasma_r', kind='bar', aspect = 2.2)
g.set_xticklabels(step=3)
plt.title("Taille du span dans le dev" , size = 15)
# Out:
# Text(0.5,1,'Taille du span dans le dev')

# %%
csvfile = pd.read_csv('taille_span_train.csv')
csvfile.head()
sns.set(font_scale=1)
g = sns.factorplot(x='taille', y='compte relatif',  data=csvfile, palette='plasma_r', kind='bar', aspect = 2.2)
g.set_xticklabels(step=3)
plt.title("Taille du span dans le train" , size = 15)
# g.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')
# Out:
# Text(0.5,1,'Taille du span dans le train')

# %%
csvfile = pd.read_csv('taille_span_dev_en_fonction_des_questions.csv')
csvfile.head()
sns.set(font_scale=3)
g = sns.factorplot('taille','compte relatif',hue="type question", palette='tab20',kind='point', data=csvfile,size=15, aspect=2.5)
plt.title("Taille du span en fonction du type de question" , size = 40)
g.set_xticklabels(step=3)

# %%
csvfile = pd.read_csv('position_span_words_dev.csv')
csvfile.head()
sns.set(font_scale=3)
g = sns.factorplot('position relative','comptage relatif',hue="class", palette='tab20',kind='point', data=csvfile,size=15, aspect=2.5)
plt.title("position relative du span par rapport aux mots(dev)" , size = 40)
g.set_xticklabels(step=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-199-a74e24eef2e4> in <module>()
#       2 csvfile.head()
#       3 sns.set(font_scale=3)
# ----> 4 g = sns.factorplot('position relative','comptage relatif',hue="class", palette='tab20',kind='point', data=csvfile,size=15, aspect=2.5)
#       5 plt.title("position relative du span par rapport aux mots(dev)" , size = 40)
#       6 g.set_xticklabels(step=1)
#
# ~/.pyenv/versions/3.4.8/lib/python3.4/site-packages/seaborn/categorical.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3489     # facets to ensure representation of all data in the final plot
#    3490     p = _CategoricalPlotter()
# -> 3491     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3492     order = p.group_names
#    3493     hue_order = p.hue_names
#
# ~/.pyenv/versions/3.4.8/lib/python3.4/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     149                 if isinstance(input, string_types):
#     150                     err = "Could not interpret input '{}'".format(input)
# --> 151                     raise ValueError(err)
#     152
#     153             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'class'

# %%
csvfile = pd.read_csv('position_span_words_train.csv')
csvfile.head()
sns.set(font_scale=3)
g = sns.factorplot('position relative','comptage relatif',hue="class", palette='tab20',kind='point', data=csvfile,size=15, aspect=2.5)
plt.title("position relative du span par rapport aux mots(train)" , size = 40)
g.set_xticklabels(step=1)
